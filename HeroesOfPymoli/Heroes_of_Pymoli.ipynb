# %%
import pandas as pd

# %%
csvfile = "Resources/purchase_data.csv"
purchase_data_df = pd.read_csv(csvfile)
purchase_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
unique_players = purchase_data_df["SN"].value_counts()
total_players = len(unique_players)
print(f"Total Players : {total_players}")
# Out:
# Total Players : 576

# %%
# PURCHASING ANALYTICS
# creating summary data frame
unique_items = purchase_data_df["Item Name"].value_counts()
num_of_unique_items = len(unique_items)
avg_price = purchase_data_df["Price"].mean()
avg_price = round(avg_price,2)
total_purchases = purchase_data_df["Item Name"].count()
total_rev = purchase_data_df["Price"].sum()

summary_df = pd.DataFrame([
    {"Number_of_Unique_Items": num_of_unique_items, 
     "Average_Price": f"${avg_price}", 
     "Number_of_Purchases": total_purchases, 
     "Total_Revenue": f"${total_rev}"}
])
summary_df
# Out:
#    Number_of_Unique_Items Average_Price  Number_of_Purchases Total_Revenue
# 0                     179         $3.05                  780      $2379.77

# %%
#purchase_data_df.dtypes
# Out:
# Purchase ID      int64
# SN              object
# Age              int64
# Gender          object
# Item ID          int64
# Item Name       object
# Price          float64
# dtype: object

# %%
# GENDER DEMOGRAPHIC
purchase_data_df["Purchase Count"] = purchase_data_df["Purchase ID"].count()
purchase_data_df["Average Purchase Price"] = purchase_data_df["Price"] / purchase_data_df["Price"].count() 
purchase_data_df["Average Total Purchase per Person"] = purchase_data_df["Price"] / purchase_data_df["SN"].count()
gender_data_df = purchase_data_df.groupby("Gender")
purchase_data_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price  Purchase Count  \
# 0    Extraction, Quickblade Of Trembling Hands   3.53             780
# 1                            Frenzied Scimitar   1.56             780
# 2                                 Final Critic   4.88             780
# 3                                  Blindscythe   3.27             780
# 4                                         Fury   1.44             780
# ..                                         ...    ...             ...
# 775                                       Wolf   3.54             780
# 776                           Exiled Doomblade   1.63             780
# 777      Celeste, Incarnation of the Corrupted   3.46             780
# 778                               Final Critic   4.19             780
# 779                                       Dawn   4.60             780
#
#      Average Purchase Price  Average Total Purchase per Person
# 0                  0.004526                           0.004526
# 1                  0.002000                           0.002000
# 2                  0.006256                           0.006256
# 3                  0.004192                           0.004192
# 4                  0.001846                           0.001846
# ..                      ...                                ...
# 775                0.004538                           0.004538
# 776                0.002090                           0.002090
# 777                0.004436                           0.004436
# 778                0.005372                           0.005372
# 779                0.005897                           0.005897
#
# [780 rows x 10 columns]

# %%
# PURCHASING ANALYSIS (GENDER)

# %%
# AGE DEMOGRAPHICS

# binning data
bins = [0, 9, 14, 19, 24, 29, 34, 39, 100]
labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40-44", "45+"]

# %%
# Out:
# 45
