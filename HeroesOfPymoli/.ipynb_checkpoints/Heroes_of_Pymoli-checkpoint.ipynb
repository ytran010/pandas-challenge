# %%
import pandas as pd

# %%
csvfile = "Resources/purchase_data.csv"
purchase_data_df = pd.read_csv(csvfile)
purchase_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
unique_players = purchase_data_df["SN"].value_counts()

total_players = len(unique_players)

print(f"Total Players : {total_players}")
# Out:
# Total Players : 576

# %%
# PURCHASING ANALYTICS
# creating summary data frame
unique_items = purchase_data_df["Item Name"].value_counts()

num_of_unique_items = len(unique_items)

avg_price = purchase_data_df["Price"].mean()

avg_price = round(avg_price,2)

total_purchases = purchase_data_df["Item Name"].count()

total_rev = purchase_data_df["Price"].sum()

summary_df = pd.DataFrame([
    {"Number_of_Unique_Items": num_of_unique_items, 
     "Average_Price": f"${avg_price}", 
     "Number_of_Purchases": total_purchases, 
     "Total_Revenue": f"${total_rev}"}
])
summary_df
# Out:
#    Number_of_Unique_Items Average_Price  Number_of_Purchases Total_Revenue
# 0                     179         $3.05                  780      $2379.77

# %%
# GENDER DEMOGRAPHIC
grouped_gender = purchase_data_df.groupby("Gender")

total_count = grouped_gender["SN"].count()

percent_players = total_count / grouped_gender["SN"].count().sum()

gender_demographics_data = pd.DataFrame({"Total Count": total_count,
                                  "Percentage of Players": percent_players*100})
gender_demographics_data["Percentage of Players"] = gender_demographics_data["Percentage of Players"].map("{:.2f}%".format)
gender_demographics_data
# Out:
#                        Total Count Percentage of Players
# Gender
# Female                         113                14.49%
# Male                           652                83.59%
# Other / Non-Disclosed           15                 1.92%

# %%
# PURCHASING ANALYSIS (GENDER)

purchase_count = grouped_gender["Purchase ID"].count()

avg_purchase_price = grouped_gender["Price"].sum() / grouped_gender["Price"].count()

avg_total_per_person = grouped_gender["Price"] / grouped_gender["SN"].count()

#gender_data = pd.DataFrame({"Purhcase Count":purchase_count,
                            #"Average Purchase Price":avg_purchase_price,
                            #"Avg Total Purchase per Person":avg_total_per_person})
#gender_data
# Out:
# /Users/petertran/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/roperator.py:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return right / left
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-67a9a41f59b2> in <module>
#       5 avg_purchase_price = grouped_gender["Price"].sum() / grouped_gender["Price"].count()
#       6
# ----> 7 avg_total_per_person = grouped_gender["Price"] / grouped_gender["SN"].count()
#       8
#       9 #gender_data = pd.DataFrame({"Purhcase Count":purchase_count,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#     341         lvalues = extract_array(left, extract_numpy=True)
#     342         rvalues = extract_array(right, extract_numpy=True)
# --> 343         result = arithmetic_op(lvalues, rvalues, op)
#     344
#     345         return left._construct_result(result, name=res_name)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     188     else:
#     189         with np.errstate(all="ignore"):
# --> 190             res_values = na_arithmetic_op(lvalues, rvalues, op)
#     191
#     192     return res_values
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     141
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#     145         if is_cmp:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     231         use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#     235
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     117
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#     121     return result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      66         _store_test_result(False)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#      70
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/roperator.py in rtruediv(left, right)
#      23
#      24 def rtruediv(left, right):
# ---> 25     return right / left
#      26
#      27
#
# ValueError: operands could not be broadcast together with shapes (3,2) (3,)

# %%
# AGE DEMOGRAPHICS

# binning data
purchase_data1_df = purchase_data_df.set_index("Age")
purchase_data1_df
bins = [0, 9, 14, 19, 24, 29, 34, 39, 44, 100]
labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40-44", "45+"]

# pd.cut(purchase_data1_df["Age"], bins, labels=labels)

age_count = purchase_data1_df["SN"].count()

age_percent = age_count / purchase_data1_df["SN"].count().sum()

age_demographics_data = pd.DataFrame({#"Age Demographics": age_dem,
                                      "Total Count": age_count,
                                      "Percentage of Players": age_percent})
age_demographics_data["Age Dem"] = pd.cut(purchase_data1_df["Age"], bins, labels=labels)
age_demographics_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-c9aaa6c79006> in <module>
#      13 age_percent = age_count / purchase_data1_df["SN"].count().sum()
#      14
# ---> 15 age_demographics_data = pd.DataFrame({#"Age Demographics": age_dem,
#      16                                       "Total Count": age_count,
#      17                                       "Percentage of Players": age_percent})
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     385
#     386         if not indexes and not raw_lengths:
# --> 387             raise ValueError("If using all scalar values, you must pass an index")
#     388
#     389         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
# PURCHASING ANALYSIS (AGE)
# Out:
#      Purchase ID             SN  Gender  Item ID  \
# Age
# 20             0        Lisim78    Male      108
# 40             1    Lisovynya38    Male      143
# 24             2     Ithergue48    Male       92
# 24             3  Chamassasya86    Male      100
# 23             4      Iskosia90    Male      131
# ..           ...            ...     ...      ...
# 21           775     Aethedru70  Female       60
# 21           776         Iral74    Male      164
# 20           777     Yathecal72    Male       67
# 7            778        Sisur91    Male       92
# 24           779      Ennrian78    Male       50
#
#                                      Item Name  Price
# Age
# 20   Extraction, Quickblade Of Trembling Hands   3.53
# 40                           Frenzied Scimitar   1.56
# 24                                Final Critic   4.88
# 24                                 Blindscythe   3.27
# 23                                        Fury   1.44
# ..                                         ...    ...
# 21                                        Wolf   3.54
# 21                            Exiled Doomblade   1.63
# 20       Celeste, Incarnation of the Corrupted   3.46
# 7                                 Final Critic   4.19
# 24                                        Dawn   4.60
#
# [780 rows x 6 columns]

# %%
# TOP SPENDERS
grouped_spenders = purchase_data_df.groupby("SN")
purchase_count = purchase_data_df["Purchase ID"].count()
total_value = purchase_data_df["Price"].sum()
avg_purchase_price = total_value / purchase_count
spenders_df = pd.DataFrame({"Purchase Count": purchase_count,
                        "Average Purchase Price": avg_purchase_price,
                        "Total Purchase Value": total_value})
spenders_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-048e110ff83f> in <module>
#       4 total_value = purchase_data_df["Price"].sum()
#       5 avg_purchase_price = total_value / purchase_count
# ----> 6 spenders_df = pd.DataFrame({"Purchase Count": purchase_count,
#       7                         "Average Purchase Price": avg_purchase_price,
#       8                         "Total Purchase Value": total_value})
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     385
#     386         if not indexes and not raw_lengths:
# --> 387             raise ValueError("If using all scalar values, you must pass an index")
#     388
#     389         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
# MOST POPULAR ITEMS
item_df = purchase_data_df[["Item ID", "Item Name", "Price"]]
grouped_item = item_df.groupby(["Item ID", "Item Name"])
purchase_count = grouped_item["Item ID"].count()
total_value = grouped_item["Price"].sum()

grouped_item = grouped_item.rename(columns={"Item Price": "Price", 
                                            "Purchase Count": purchase_count,
                                            "Total Purchase Value": total_value})
grouped_item
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-62ac5eeb520f> in <module>
#       5 total_value = grouped_item["Price"].sum()
#       6
# ----> 7 grouped_item = grouped_item.rename(columns={"Item Price": "Price",
#       8                                             "Purchase Count": purchase_count,
#       9                                             "Total Purchase Value": total_value})
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'rename'

# %%
# MOST PROFITABLE ITEMS
